# %%
import pandas as pd

# %%
df = pd.read_excel("Case Study_Fruit Juices.xlsx")

# %%
df
# Out:
#       resp_id  Brand  Aware  imagery_1  imagery_2  imagery_3  imagery_4  \
# 0           1      1      1          3          3          3          3
# 1           1      2      1          3          1          3          1
# 2           1      3      1          3          1          3          2
# 3           2      1      1          4          2          3          2
# 4           2      2      1          2          3          1          3
# 5           2      3      1          2          2          3          1
# 6           3      1      1          1          1          2          1
# 7           3      2      1          3          2          2          3
# 8           3      3      1          2          3          2          3
# 9           4      1      1          4          4          3          4
# 10          4      2      1          3          1          3          1
# 11          4      3      1          3          3          3          4
# ...

# %%
dfa = df.drop(columns=['resp_id','Brand', 'Aware', 'OL'])

# %%
dfa
# Out:
#       imagery_1  imagery_2  imagery_3  imagery_4  imagery_5  imagery_6  \
# 0             3          3          3          3          3          2
# 1             3          1          3          1          2          5
# 2             3          1          3          2          2          3
# 3             4          2          3          2          2          2
# 4             2          3          1          3          2          4
# 5             2          2          3          1          2          1
# 6             1          1          2          1          2          3
# 7             3          2          2          3          2          4
# 8             2          3          2          3          2          4
# 9             4          4          3          4          4          4
# 10            3          1          3          1          2          2
# 11            3          3          3          4          3          2
# ...

# %%
from factor_analyzer import FactorAnalyzer

# %%
fa = FactorAnalyzer()

# %%
fa.analyze(dfa, 3, rotation=None)

# %%
fa.loadings
# Out:
#              Factor1   Factor2
# imagery_1   0.732420 -0.043145
# imagery_2   0.676145 -0.054466
# imagery_3   0.852896 -0.034731
# imagery_4   0.678476 -0.074678
# imagery_5   0.872929 -0.051629
# imagery_6   0.110739 -0.001623
# imagery_7   0.224820  0.028818
# imagery_8   0.323344  0.004140
# imagery_9   0.218816  0.027881
# imagery_10  0.793598 -0.043996
# attitude_1  0.076520  0.871168
# attitude_2  0.079685  0.711031
# attitude_3  0.074305  0.703362
# attitude_4 -0.030677 -0.654203
# attitude_5 -0.037410 -0.516122
